# %% [markdown]
# # Problemas de Negócios e Visualização
#
# Ao tratar de negócios, é importante ser sensível aos problemas específicos que aquele negócio enfrenta.
#
# ## Visualização de dados
#
# Uma das ferramentas mais importantes do cientista de dados são suas visualizações. Muitas vezes é mais fácil entender um conjunto de dados através de representações gráficas que pela representação numérica. Existem vários tipos diferentes de gráficos,

# %%
import pandas as pd

dados = pd.read_csv("pokemon_data.csv")

# %%
# Análise exploratória dos dados
colunas = dados.columns
selecionados = dados['Name'][71:75]
selecionados
# Out:
# 71    AlakazamMega Alakazam
# 72                   Machop
# 73                  Machoke
# 74                  Machamp
# Name: Name, dtype: object

# %%
# Análise de estatística descritiva
sumario = dados.describe()
print(sumario)
print(sumario['HP'])

print(f"A média do HP é {dados['HP'].mean()}")

water = dados[dados["Type 1"] == "Water"]
print(f"A média do HP Water é {water['HP'].mean()}")

agrupados = dados[['HP',
                   'Type 1']].groupby('Type 1').mean().sort_values('HP',ascending=False)
# Out:
#                 #          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.000000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750   69.258750   79.001250   73.842500   72.820000   71.902500
# std    208.343798   25.534669   32.457366   31.183501   32.722294   27.828916
# min      1.000000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    184.750000   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    364.500000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    539.250000   80.000000  100.000000   90.000000   95.000000   90.000000
# max    721.000000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 25%     45.000000     2.00000
# 50%     65.000000     3.00000
# 75%     90.000000     5.00000
# max    180.000000     6.00000
# count    800.000000
# mean      69.258750
# std       25.534669
# min        1.000000
# 25%       50.000000
# 50%       65.000000
# 75%       80.000000
# max      255.000000
# Name: HP, dtype: float64
# A média do HP é 69.25875
# A média do HP Water é 72.0625

# %%
# Visualização de dados
## Relacionamentos
# Scatter
colors=['#145da0','#0c2d48','#2e8bc0','#b1d4e0']
ax = dados.plot.scatter(x="Attack",y="Defense",c=colors[2])

# %%
# Bolhas
# dados['HP'] = dados['HP']*0.5
# dados['Sp. Atk'] = dados['Sp. Atk']*5
dados.plot.scatter(x="Attack",y="Defense",s="HP",alpha=0.5)
# Out:
# <AxesSubplot:xlabel='Attack', ylabel='Defense'>

# %%
# Comparação
# Linha
dados[['#',"HP"]].plot(x='#',y='HP')
# Barras
dados[100:101].plot.bar(ylim=[0,160],xlabel=dados["Name"][100])
# Out:
# <AxesSubplot:xlabel='Haunter'>

# %%
# Distribuição
# Histograma
dados['HP'].plot.hist()
# dados['HP'].plot.box()

agrupados.plot.box()
# Out:
# <AxesSubplot:>
